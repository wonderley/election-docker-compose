# %% [markdown]
# # Data Loader
#
# Script to read in CSV files and export to PostgreSQL.

# %%
#Not all these dependencies are needed to load the data, but these are good for notebook analysis

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sqlalchemy import create_engine

pd.set_option('max_columns', 500)

# %%
def importer(path):
    '''Reads in and formats CSV accordingly'''
    df = pd.read_csv(path)
    
    return df

path = './StateEthicsReport.csv'

campaign = importer(path)

# %%
campaign.head()
# Out:
#        FilerID      Type       LastName    FirstName                  Address  \
# 0  C2017000285  Monetary  Arford-Tasker        Nancy    9175 SW Arrow Wood Dr
# 1  C2017000285  Monetary          Arias  L. Patricia  2112 Chesterfield Dr NE
# 2  C2017000285  Monetary       Anderson        Ann S         2002 Amberley Dr
# 3  C2017000285  Monetary       Anderson        Carol       2418 Boulder Rd SE
# 4  C2017000285  Monetary       Anderson       Joseph           2646 Nakai Trl
#
#         City State         Zip  PAC         Occupation  \
# 0   Portland    OR  97223-7265  NaN            Retired
# 1    Atlanta    GA  30345-3706  NaN           Attorney
# 2      Evans    GA  30809-6752  NaN       Not Employed
# 3    Atlanta    GA  30316-3673  NaN          Professor
# 4  Flagstaff    AZ  86005-3660  NaN  College Professor
#
#                             Employer                   Date Election  \
# 0                            Retired  8/30/2018 12:00:00 AM  General
# 1  Orange Business Services US, Inc.  8/10/2018 12:00:00 AM  General
# 2                       Not Employed  7/14/2018 12:00:00 AM  General
# 3                   Emory University  7/20/2018 12:00:00 AM  General
# 4           Northern Ariz university  9/26/2018 12:00:00 AM  General
#
#    Election_Year  Cash_Amount  In_Kind_Amount In_Kind_Description  \
# 0           2018         10.0             0.0                 NaN
# 1           2018         15.0             0.0                 NaN
# 2           2018        125.0             0.0                 NaN
# 3           2018         50.0             0.0                 NaN
# 4           2018        250.0             0.0                 NaN
#
#   Candidate_FirstName Candidate_MiddleName Candidate_LastName  \
# 0              Stacey               Yvonne             Abrams
# 1              Stacey               Yvonne             Abrams
# 2              Stacey               Yvonne             Abrams
# 3              Stacey               Yvonne             Abrams
# 4              Stacey               Yvonne             Abrams
#
#    Candidate_Suffix             Committee_Name
# 0               NaN  Stacy Abrams for Governor
# 1               NaN  Stacy Abrams for Governor
# 2               NaN  Stacy Abrams for Governor
# 3               NaN  Stacy Abrams for Governor
# 4               NaN  Stacy Abrams for Governor

# %%
def id_maker(df, col_name, identity_fields, base_number=1000000000):
    '''Read in DataFrame and a list of fields used to identify an entity. Assign a number to those fields.'''
    
    match_table = df[identity_fields].drop_duplicates().copy()
    match_table[col_name] = np.arange(base_number, base_number+len(match_table))
    
    df = pd.merge(df,
                  match_table,
                  on=identity_fields,
                  how='left')
    
    return df[col_name]



#id_check = id_maker(df = campaign, col_name = 'ContributorId', identity_fields = ['LastName', 'FirstName', 'Zip', 'Address'])

# %%
def contributor(df, key_col='ContributorId'):
    '''Parse and prep contributor info from the database. Contributor schema:
    
    ContributorId
    LastName
    FirstName
    Address1
    Address2
    City
    State
    Zip
    PAC
    Occupation
    Employer'''
    
    contributor = df.copy() #copy dataframe so as not to impact the data in the original location
    
    #Prepare dataframe to use same fields as in schema
    contributor_fields = ['ContributorId', 'LastName', 'FirstName', 'Address1', 'Address2',
                          'City', 'State', 'Zip', 'PAC', 'Occupation', 'Employer']
    
    contributor[key_col] = id_maker(df=contributor, 
                                    col_name=key_col, 
                                    identity_fields=['LastName', 'FirstName', 'Address', 'Zip'])
    
    contributor['Address1'] = contributor['Address']
    contributor['Address2'] = np.nan
    
    contributor = contributor[contributor_fields].drop_duplicates(subset=['ContributorId']).reset_index(drop=True)
    
    return contributor

# %%
contributors = contributor(campaign)

# %%
#Builds the key to connect with Postgres Database using sqlalchemy and pandas. password can be string of choice, make sure you preserve the punctuation in each string
file = open('getin.txt')
driver = 'postgresql+pg8000://'
user = 'postgres:'
pwd = file.read()
host = '@db'
database = '/electionmoney'

key = driver + user + pwd + host + database
key
# Out:
# 'postgresql+pg8000://postgres:pw@db/electionmoney'

# %%
#Establish the connection using the key

from sqlalchemy import create_engine
engine = create_engine(key)
connection = engine.connect()

# %%
connection

# %%
contributors.to_sql('Contributor', connection, if_exists='append', index=False) #send the table, appending rows that already exist rather than deleting and replacing

# %%
pd.read_sql('Contributor', connection) #readout of the data from the SQL database
# Out:
#        ContributorId                         LastName     FirstName  \
# 0         1000000000                    Arford-Tasker         Nancy
# 1         1000000001                            Arias   L. Patricia
# 2         1000000002                         Anderson         Ann S
# 3         1000000003                         Anderson         Carol
# 4         1000000004                         Anderson        Joseph
# 5         1000000005                         Anderson           Lee
# 6         1000000006                          Appleby  Elizabeth P.
# 7         1000000007                        Applegate          Mary
# 8         1000000008                             Arce         Ellen
# 9         1000000009                           Archer      Kimberly
# 10        1000000010                        Archuleta        Latika
# 11        1000000011                           Arians     Christine
# 12        1000000012                            Ariza        Carlos
# 13        1000000013                            Arkin     Michaelle
# 14        1000000014                           Armand       Karen M
# 15        1000000015                        Armstrong       Shannon
# 16        1000000016                           Arnold          Mark
# 17        1000000017                          Ashburg     Calvin E.
# 18        1000000018                         Ashburne       Michael
# 19        1000000019                            Adams          Rick
# 20        1000000020                            Adams       V. Toni
# 21        1000000021                    Adams-Pickett         Donna
# 22        1000000022                          Addison     Albert D.
# 23        1000000023                         Aderhold         Susan
# 24        1000000024                            Adler         David
# 25        1000000025                          Aferiat          Paul
# 26        1000000026  AFGE Political Action Committee          None
# 27        1000000027                         Albrecht      Martha L
# 28        1000000028                      Aldenderfer       Charles
# 29        1000000029                         Alemanne        Nicole
# ...              ...                              ...           ...
# 15358     1000015358                          Robbins    Richard K.
# 15359     1000015359                         Roberson     Stephanie
# 15360     1000015360                           Robert     Christine
# 15361     1000015361                          Roberts       Chelsea
# 15362     1000015362                          Roberts       William
# 15363     1000015363                          Skellie          Fred
# 15364     1000015364                            Smith        Andrea
# 15365     1000015365                            Smith       Branden
# 15366     1000015366                         Robinson      Karen E.
# 15367     1000015367                         Robinson        Sophie
# 15368     1000015368                          Pickett         Elmer
# 15369     1000015369                           Planer         Mindy
# 15370     1000015370                          Sassard  Jacqueline B
# 15371     1000015371                  SassenVanElsloo        Saskia
# 15372     1000015372                         Saunders        Elaine
# 15373     1000015373                            Russo       Tiffany
# 15374     1000015374                        Rutcofsky         Emily
# 15375     1000015375                             Ross     Donata R.
# 15376     1000015376                             Ross   Patricia A.
# 15377     1000015377                       Ross-Jones          Lisa
# 15378     1000015378                           Rosser         Brian
# 15379     1000015379                            Regas         Diane
# 15380     1000015380                        Reibstein         Karen
# 15381     1000015381                          Reinish         James
# 15382     1000015382                          Robbins         Peter
# 15383     1000015383                          Roberts         Julie
# 15384     1000015384                          Roberts       Shannon
# 15385     1000015385                         Robinson         Brian
# 15386     1000015386                   Resurgent Left          None
# 15387     1000015387                         Reynolds      Veatrice
#
#                          Address1  Address2                City State  \
# 0           9175 SW Arrow Wood Dr       NaN            Portland    OR
# 1         2112 Chesterfield Dr NE       NaN             Atlanta    GA
# 2                2002 Amberley Dr       NaN               Evans    GA
# 3              2418 Boulder Rd SE       NaN             Atlanta    GA
# 4                  2646 Nakai Trl       NaN           Flagstaff    AZ
# 5                50 Yacht Cove Dr       NaN  Hilton Head Island    SC
# 6                 68 Maple Ave NW       NaN            Marietta    GA
# 7                1207 Ridge Ave N       NaN              Tifton    GA
# 8                      PO box 588       NaN          Marshfield    MA
# 9          863 Forest Ridge Dr SE       NaN            Marietta    GA
# 10              6997 Glen Cove Ln       NaN      Stone Mountain    GA
# 11               133 Southlook Ln       NaN            Eatonton    GA
# 12             211 Lakestone Pkwy       NaN           Woodstock    GA
# 13             223 Westchester Dr       NaN             Decatur    GA
# 14             123 Mockingbird Ln       NaN             Decatur    GA
# 15              1160 Sandstone Dr       NaN                Vail    CO
# 16         1126 N Highland Ave NE       NaN             Atlanta    GA
# 17               5181 Manitou Way       NaN      Stone Mountain    GA
# 18                  539 Summit Dr       NaN              Pinole    CA
# 19                    234 Pine Dr       NaN       Pine Mountain    GA
# 20     1002 Martin Luther King Dr       NaN             Hayward    CA
# 21              1420 Aylesbury Dr       NaN               Evans    GA
# 22                475 10th Ave NW       NaN               Cairo    GA
# 23          1981 Wellbourne Dr NE       NaN             Atlanta    GA
# 24         1011 Blue Beech Pointe       NaN              Athens    GA
# 25                    126 5th Ave       NaN            New York    NY
# 26                     80 F St NW       NaN          Washington    DC
# 27            2833 Plaza Amarilla       NaN            Santa Fe    NM
# 28              555 Sun Valley Dr       NaN             Roswell    GA
# 29               2615 NW 52nd Ave       NaN         Gainesville    FL
# ...                           ...       ...                 ...   ...
# 15358                 1120 Nye St       NaN          San Rafael    CA
# 15359         1829 Buckhead Ln NE       NaN             Atlanta    GA
# 15360            5601 Park Oak Pl       NaN         Los Angeles    CA
# 15361               77 W 126th St       NaN            New York    NY
# 15362             166 W Ridge Way       NaN             Roswell    GA
# 15363         2303 Dancing Fox Rd       NaN             Decatur    GA
# 15364    7033 Bennington Woods Dr       NaN          Pittsburgh    PA
# 15365                   2 Gold St       NaN            New York    NY
# 15366              230 Palmita Pl       NaN       Mountain View    CA
# 15367      61 Stratham Heights Rd       NaN            Stratham    NH
# 15368           1420 Aylesbury Dr       NaN               Evans    GA
# 15369    1299 N Morningside Dr NE       NaN             Atlanta    GA
# 15370              34 Berkeley Rd       NaN          Charleston    SC
# 15371          37 Washington Sq W       NaN            New York    NY
# 15372      3101 New Mexico Ave NW       NaN          Washington    DC
# 15373         5647 Old Chester Rd       NaN            Bethesda    MD
# 15374               175 W 12th St       NaN            New York    NY
# 15375              275 13th St NE       NaN             Atlanta    GA
# 15376             56 Laurel Dr NE       NaN             Atlanta    GA
# 15377            2991 Cadbury Trl       NaN          Snellville    GA
# 15378              104 Jackson St       NaN             Calhoun    GA
# 15379             616 The Alameda       NaN            Berkeley    CA
# 15380           6322 Camino Corto       NaN           San Diego    CA
# 15381          336 Central Park W       NaN            New York    NY
# 15382                  49 8th Ave       NaN            Brooklyn    NY
# 15383          816 S Clarizz Blvd       NaN         Bloomington    IN
# 15384                218 Woods Rd       NaN            Glenside    PA
# 15385                  PO Box 100       NaN           Flat Rock    NC
# 15386             770 S Grand Ave       NaN         Los Angeles    CA
# 15387          1041 Daventry Xing       NaN           Woodstock    GA
#
#               Zip  PAC                         Occupation  \
# 0      97223-7265  NaN                            Retired
# 1      30345-3706  NaN                           Attorney
# 2      30809-6752  NaN                       Not Employed
# 3      30316-3673  NaN                          Professor
# 4      86005-3660  NaN                  College Professor
# 5      29928-1518  NaN                            Retired
# 6      30064-2220  NaN                            Retired
# 7      31794-3955  NaN                       Not Employed
# 8      02050-0588  NaN                         pharmacist
# 9      30067-7176  NaN                    Systems analyst
# 10     30087-6312  NaN                 Real Estate Broker
# 11     31024-5413  NaN                       Not Employed
# 12     30188-5425  NaN                 IT Service Manager
# 13     30030-1119  NaN                       Not Employed
# 14     30030-1160  NaN                         Retired RN
# 15     81657-4408  NaN                       Not Employed
# 16     30306-3494  NaN                            Founder
# 17     30087-4263  NaN                            Retired
# 18     94564-1640  NaN                           Attorney
# 19     31822-2336  NaN                            Retired
# 20     94541-4307  NaN                       Not Employed
# 21     30809-8215  NaN                          Physician
# 22     39828-1952  NaN                       Not Employed
# 23     30324-4903  NaN              Information Requested
# 24     30606-7616  NaN                             Writer
# 25     10011-5606  NaN                          architect
# 26     20001-1528  NaN                               None
# 27     87507-6507  NaN                       Not employed
# 28     30076-5625  NaN                             C.P.A.
# 29     32605-6210  NaN                           Educator
# ...           ...  ...                                ...
# 15358  94901-2946  NaN                              Owner
# 15359  30324-6103  NaN                          physician
# 15360  90068-2545  NaN                       Not Employed
# 15361  10027-3981  NaN  Health care fundraising/investing
# 15362  30076-6422  NaN                          President
# 15363  30032-7418  NaN                       Not Employed
# 15364  15237-6371  NaN                           attorney
# 15365  10038-4853  NaN               Senior Data Engineer
# 15366  94041-1328  NaN                    Product Manager
# 15367  03885-2547  NaN                            Student
# 15368  30809-8215  NaN                     Administration
# 15369  30306-3336  NaN                           attorney
# 15370  29407-7420  NaN                       Not Employed
# 15371  10011-9181  NaN                          Professor
# 15372  20016-5916  NaN                     Sales Director
# 15373  20814-1035  NaN                           attorney
# 15374  10011-8275  NaN                             Lawyer
# 15375  30309-5505  NaN                                CEO
# 15376  30342-4102  NaN                            Retired
# 15377  30039-7051  NaN                 Information needed
# 15378  30701-2038  NaN                          Candidate
# 15379  94707-1602  NaN                                CEO
# 15380  92120-3108  NaN                       Not Employed
# 15381  10025-7107  NaN                         art dealer
# 15382  11217-3901  NaN                Real Estate Manager
# 15383  47401-5518  NaN               art gallery director
# 15384  19038-1431  NaN                          Geologist
# 15385  28731-0100  NaN                  Performing Artist
# 15386  90017-3957  NaN                               None
# 15387  30188-7137  NaN                         Supervisor
#
#                                                Employer
# 0                                               Retired
# 1                     Orange Business Services US, Inc.
# 2                                          Not Employed
# 3                                      Emory University
# 4                              Northern Ariz university
# 5                                               Retired
# 6                                                  None
# 7                                          Not Employed
# 8                                        Cognosante LLC
# 9                                      Secureworks inc.
# 10                                                   RE
# 11                                         Not Employed
# 12                                       General Motors
# 13                                         Not Employed
# 14                                                 None
# 15                                         Not Employed
# 16                             Gotham Media Corporation
# 17                                              Retired
# 18                                                 Self
# 19                                              Retired
# 20                                         Not Employed
# 21                                                 Self
# 22                                         Not Employed
# 23                                Information Requested
# 24                                                 Self
# 25                                                 self
# 26                                                 None
# 27                                         Not employed
# 28                           The Aldenderfer Group P.C.
# 29     Unitarian Universalist Fellowship of Gainesville
# ...                                                 ...
# 15358                                           WAREHAM
# 15359                                N. Metro Radiology
# 15360                                      Not Employed
# 15361                         Mount Sinai Health System
# 15362                      Bill Roberts Electrical inc.
# 15363                                      Not Employed
# 15364                                UPMC Health System
# 15365                                    Publicis Media
# 15366                                        TangiblePS
# 15367                                           Student
# 15368                            Augusta Women's Health
# 15369                             Arnall Golden Gregory
# 15370                                      Not Employed
# 15371                                          Columbia
# 15372                                         Simpli.fi
# 15373                                           verizon
# 15374                      Milbank Tweed Hadley &McCloy
# 15375                     Concessions International LLC
# 15376                                      Not Employed
# 15377                                Information needed
# 15378                                       Georgia HD5
# 15379                                               TPL
# 15380                                      Not Employed
# 15381                                              self
# 15382                                    Robbins Agency
# 15383             Ivy Tech Community College of Indiana
# 15384                       Stantec Consulting Services
# 15385                                              Self
# 15386                                              None
# 15387                      State Farm Insurance Company
#
# [15388 rows x 11 columns]
